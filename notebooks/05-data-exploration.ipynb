# %%
import pandas as pd
import altair as alt

# %%
data = pd.read_csv("../data/processed/val/data.csv")

# %%
data.head()
# Out:
#                      file  superflux  timestamps  energy         rms  \
# 0  Media-106117(7.0-17.0)    0.00000       0.025     0.0  10931.0100
# 1  Media-106117(7.0-17.0)    0.01429       0.075     0.0   8131.4927
# 2  Media-106117(7.0-17.0)    0.00255       0.125     0.0   7341.4097
# 3  Media-106117(7.0-17.0)    0.00910       0.175     0.0   6329.5005
# 4  Media-106117(7.0-17.0)    0.00834       0.225     0.0   8991.6530
#
#    sound_preassure_level        welch       mean  kurtosis     skew  \
# 0              -15.14828  191984540.0  -62.78640  16.12752  0.15613
# 1              -16.62181  136304050.0  165.57007   1.56413  0.22568
# 2              -16.52187   90166750.0   74.52608   0.62528  0.26574
# 3              -17.30260   61237988.0 -144.47256   0.04905  0.25738
# 4              -18.24260   67646690.0  -24.68912   0.01492  0.26310
#
#     variation  onset
# 0 -1950.09830  False
# 1   153.56071  False
# 2  -178.40205   True
# 3  -156.39023  False
# 4  -290.04600  False

# %%
file = data["file"][4]

# %%
base = alt.Chart(data[data["file"]==file])

superflux = base.mark_line().encode(x="timestamps", y="superflux")

onsets = alt.Chart(data[data["file"]==file][data["onset"]]).mark_rule(color='red').encode(
    x='timestamps'
)

(superflux + onsets).properties(width=1200).interactive()
# Out:
# /tmp/ipykernel_596740/2715843676.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   onsets = alt.Chart(data[data["file"]==file][data["onset"]]).mark_rule(color='red').encode(
# alt.LayerChart(...)

# %%
base = alt.Chart(data[data["file"]==file])

features = base.mark_line().encode(x="timestamps", y=alt.Y(alt.repeat("row"), type='quantitative')).properties(width=1200)

onsets = alt.Chart(data[data["file"]==file][data["onset"]]).mark_rule(color='red').encode(
    x='timestamps'
)

(features + onsets).repeat(row=["superflux", "welch", "kurtosis"])
# Out:
# /tmp/ipykernel_596740/2889062231.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   onsets = alt.Chart(data[data["file"]==file][data["onset"]]).mark_rule(color='red').encode(
# alt.RepeatChart(...)

# %%
alt.Chart(data.head(100)).mark_circle(opacity=0.5).encode(
    alt.X(alt.repeat("column"), type='quantitative'),
    alt.Y(alt.repeat("row"), type='quantitative'),
    color='onset:N'
).properties(
    width=100,
    height=100
).repeat(
    row=["superflux", "energy", "welch", "kurtosis", "skew"],
    column=list(reversed(["superflux", "energy", "welch", "kurtosis", "skew"]))
).interactive()
# Out:
# alt.RepeatChart(...)
