# %%
import pandas as pd
import altair as alt

# %%
data = pd.read_csv("../data/processed/val/data.csv")

# %%
data.head()
# Out:
#                       file  superflux        energy        rms  \
# 0  Media-103515(19.7-29.7)    0.00000  1.854257e+10  11829.067
# 1  Media-103515(19.7-29.7)    0.67023  5.774538e+10   8706.333
# 2  Media-103515(19.7-29.7)    0.00030  4.272828e+10   7296.478
# 3  Media-103515(19.7-29.7)    0.00017  3.804206e+10   4892.303
# 4  Media-103515(19.7-29.7)    0.44279  3.252422e+10   4125.005
#
#    sound_preassure_level       welch       mean  kurtosis     skew  variation  \
# 0              -16.04423  23887228.0  -97.99023   3.78939  0.08069  -52.71864
# 1              -14.21874  41914464.0  -20.98438   0.31893 -0.17229 -303.80963
# 2              -14.86607  25699324.0   44.87402  -0.13543  0.44628  131.86375
# 3              -13.36547  26550460.0  386.51025   0.67891  0.02318   18.16960
# 4              -18.32991  17450054.0  248.43115  -0.19117 -0.62259   15.95452
#
#    onset  timestamps
# 0   True        0.05
# 1  False        0.15
# 2   True        0.25
# 3   True        0.35
# 4  False        0.45

# %%
file = data["file"][0]

# %%
base = alt.Chart(data[data["file"]==file])

superflux = base.mark_line().encode(x="timestamps", y="superflux")

onsets = alt.Chart(data[data["file"]==file][data["onset"]]).mark_rule(color='red').encode(
    x='timestamps'
)

(superflux + onsets).properties(width=1200).interactive()
# Out:
# /tmp/ipykernel_61728/2715843676.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   onsets = alt.Chart(data[data["file"]==file][data["onset"]]).mark_rule(color='red').encode(
# alt.LayerChart(...)

# %%
base = alt.Chart(data[data["file"]==file])

features = base.mark_line().encode(x="timestamps", y=alt.Y(alt.repeat("row"), type='quantitative')).properties(width=1200)

onsets = alt.Chart(data[data["file"]==file][data["onset"]]).mark_rule(color='red').encode(
    x='timestamps'
)

(features + onsets).repeat(row=["superflux", "welch", "kurtosis"])
# Out:
# /tmp/ipykernel_61728/2889062231.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   onsets = alt.Chart(data[data["file"]==file][data["onset"]]).mark_rule(color='red').encode(
# alt.RepeatChart(...)

# %%
alt.Chart(data).mark_circle(opacity=0.5).encode(
    alt.X(alt.repeat("column"), type='quantitative'),
    alt.Y(alt.repeat("row"), type='quantitative'),
    color='onset:N'
).properties(
    width=100,
    height=100
).repeat(
    row=["superflux", "energy", "welch", "kurtosis", "skew"],
    column=list(reversed(["superflux", "energy", "welch", "kurtosis", "skew"]))
).interactive()
# Out:
# alt.RepeatChart(...)
