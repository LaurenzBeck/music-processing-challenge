# %%
import pandas as pd
import altair as alt

# %%
data = pd.read_csv("../data/processed/val/data.csv")

# %%
data.head()
# Out:
#       file  superflux  timestamps  superflux.diff  superflux.ewm3  \
# 0  train20    0.00000        0.02             NaN         0.00000
# 1  train20    0.02238        0.06         0.15453         0.10302
# 2  train20    0.02033        0.10        -0.15273         0.04518
# 3  train20    0.01386        0.14        -0.00129         0.02136
# 4  train20    0.01862        0.18         0.02761         0.02485
#
#    superflux.diff.ewm3  superflux.ewm6  superflux.diff.ewm6        energy  \
# 0                  NaN         0.00000                  NaN  1.572758e+11
# 1              0.02238         0.00454              0.00779  1.646836e+11
# 2              0.00609         0.00398              0.00063  1.707700e+11
# 3             -0.00109         0.00418              0.00088  1.546467e+11
# 4              0.00203         0.00415              0.00039  1.371550e+11
#
#     energy.diff  ...  skew.diff.ewm3  skew.ewm6  skew.diff.ewm6       std  \
# 0           NaN  ...             NaN   -0.42180             NaN  29.61466
# 1 -2.791957e+10  ...        -0.08452   -0.56524        -0.04995 -20.54739
# 2  3.048177e+10  ...        -0.00254   -0.65543        -0.02565 -10.05669
# 3  6.116963e+10  ...         0.05464   -0.68136        -0.16361  -0.33333
# 4  3.431902e+10  ...         0.04001   -0.62542         0.02611  12.09161
#
#     std.diff   std.ewm3  std.diff.ewm3  std.ewm6  std.diff.ewm6  onset
# 0        NaN  168.55586            NaN -68.75465            NaN  False
# 1    6.74164  159.89948      130.56764 -81.15923       -3.21784   True
# 2 -113.63612  112.61533       59.63361 -80.68554       42.72026  False
# 3  107.27362   98.34711      -30.05754 -87.15874        5.72335   True
# 4  -49.54800  160.87814       10.50688 -63.72537        4.33555   True
#
# [5 rows x 51 columns]

# %%
file = data["file"][4]

# %%
base = alt.Chart(data[data["file"]==file])

superflux = base.mark_line().encode(x="timestamps", y="superflux")

onsets = alt.Chart(data[data["file"]==file][data["onset"]]).mark_rule(color='red').encode(
    x='timestamps'
)

(superflux + onsets).properties(width=1200).interactive()
# Out:
# /tmp/ipykernel_5586/2715843676.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   onsets = alt.Chart(data[data["file"]==file][data["onset"]]).mark_rule(color='red').encode(
# alt.LayerChart(...)

# %%
base = alt.Chart(data[data["file"]==file])

features = base.mark_line().encode(x="timestamps", y=alt.Y(alt.repeat("row"), type='quantitative')).properties(width=1200)

onsets = alt.Chart(data[data["file"]==file][data["onset"]]).mark_rule(color='red').encode(
    x='timestamps'
)

(features + onsets).repeat(row=["superflux", "welch", "kurtosis"])
# Out:
# /tmp/ipykernel_5586/2889062231.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   onsets = alt.Chart(data[data["file"]==file][data["onset"]]).mark_rule(color='red').encode(
# alt.RepeatChart(...)

# %%
alt.Chart(data.head(100)).mark_circle(opacity=0.5).encode(
    alt.X(alt.repeat("column"), type='quantitative'),
    alt.Y(alt.repeat("row"), type='quantitative'),
    color='onset:N'
).properties(
    width=100,
    height=100
).repeat(
    row=["superflux", "energy", "welch", "kurtosis", "skew"],
    column=list(reversed(["superflux", "energy", "welch", "kurtosis", "skew"]))
).interactive()
# Out:
# alt.RepeatChart(...)
