# %%
import pandas as pd
import altair as alt

# %%
data = pd.read_csv("../data/processed/val/data.csv")

# %%
data.head()
# Out:
#                       file  superflux  timestamps  superflux.diff  \
# 0  Media-105801(11.0-21.0)    0.00000    0.035714             NaN
# 1  Media-105801(11.0-21.0)    0.12512    0.107143         0.12512
# 2  Media-105801(11.0-21.0)    0.00839    0.178571        -0.11673
# 3  Media-105801(11.0-21.0)    0.01644    0.250000         0.00805
# 4  Media-105801(11.0-21.0)    0.05038    0.321429         0.03394
#
#    superflux.ewm3  superflux.diff.ewm3  superflux.ewm6  superflux.diff.ewm6  \
# 0         0.00000                  NaN         0.00000                  NaN
# 1         0.08341              0.00007         0.01019              0.28326
# 2         0.04054              0.01734         0.08044             -0.03621
# 3         0.02769              0.04399         0.06176             -0.01276
# 4         0.03940             -0.02744         0.04334              0.04730
#
#          energy   energy.diff  ...  skew.diff.ewm3  skew.ewm6  skew.diff.ewm6  \
# ...

# %%
file = data["file"][4]

# %%
base = alt.Chart(data[data["file"]==file])

superflux = base.mark_line().encode(x="timestamps", y="superflux")

onsets = alt.Chart(data[data["file"]==file][data["onset"]]).mark_rule(color='red').encode(
    x='timestamps'
)

(superflux + onsets).properties(width=1200).interactive()
# Out:
# /tmp/ipykernel_11940/2715843676.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   onsets = alt.Chart(data[data["file"]==file][data["onset"]]).mark_rule(color='red').encode(
# alt.LayerChart(...)

# %%
base = alt.Chart(data[data["file"]==file])

features = base.mark_line().encode(x="timestamps", y=alt.Y(alt.repeat("row"), type='quantitative')).properties(width=1200)

onsets = alt.Chart(data[data["file"]==file][data["onset"]]).mark_rule(color='red').encode(
    x='timestamps'
)

(features + onsets).repeat(row=["superflux", "welch", "kurtosis"])
# Out:
# /tmp/ipykernel_11940/2889062231.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   onsets = alt.Chart(data[data["file"]==file][data["onset"]]).mark_rule(color='red').encode(
# alt.RepeatChart(...)

# %%
alt.Chart(data.head(100)).mark_circle(opacity=0.5).encode(
    alt.X(alt.repeat("column"), type='quantitative'),
    alt.Y(alt.repeat("row"), type='quantitative'),
    color='onset:N'
).properties(
    width=100,
    height=100
).repeat(
    row=["superflux", "energy", "welch", "kurtosis", "skew"],
    column=list(reversed(["superflux", "energy", "welch", "kurtosis", "skew"]))
).interactive()
# Out:
# alt.RepeatChart(...)
